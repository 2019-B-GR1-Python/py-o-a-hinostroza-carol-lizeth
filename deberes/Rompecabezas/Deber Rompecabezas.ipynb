# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import ndimage
from scipy import misc

# %%
mapache= misc.face()
mapache
plt.imshow(mapache)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
mapache1=np.copy(mapache)
plt.imshow(mapache1[100:800, 250:600], cmap=plt.cm.gray)
plt.imshow(mapache1[100:800, 250:600], cmap=plt.cm.gray, interpolation='nearest')
plt.imshow(mapache[0:7])

# %%
import numpy as np

# %%
import cv2

# %%
mapache1=np.copy(mapache)
new =plt.imshow(mapache1[100:500, 250:600], cmap=plt.cm.gray)
print("kol", new)
# Out:
# kol AxesImage(54,36;334.8x217.44)

# %%
import os
import image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-ca407605cb2a> in <module>
#       1 import os
# ----> 2 import image
#
# ModuleNotFoundError: No module named 'image'

# %%
def crop(infile,height,width): 
    im = Image.open(infile) imgwidth, imgheight = im.size 
    for i in range(imgheight//height): 
        for j in range(imgwidth//width): 
            box = (j*width, i*height, (j+1)*width, (i+1)*height) 
            yield im.crop(box) 
            if __name__=='__main__': infile=... height=... width=... start_num=... for k,piece in enumerate(crop(infile,height,width),start_num): img=Image.new('RGB', (height,width), 255) img.paste(piece) path=os.path.join('/tmp',"IMG-%s.png" % k) img.save(path)

# %%
def menu ():
    print ("Hola: ¡¡ Selecciona la acción que deseas realizar!!")
    print ("\t1 - JUGAR")
    print ("\t2 - SALIR")
       
while True:
    menu()
    opcionMenu = input("Elija una opción ")
    if opcionMenu =="1":
        print("EMPEZAMOS")
        posicion_a = input("Parte de la imagen a mover: ")
        posicion_b = input("Posicion a la que desea mover: ")
        temporal = piezasI[int(posicion_a)]
        piezasI[int(posicion_a)] = piezasI[int(posicion_b)]
        piezasI[int(posicion_b)] = temporal
        
        desorden = np.concatenate(list(map(lambda x: rompecabezas1[x],piezasI)))
        plt.imshow(desorden)
        plt.show()
    elif opcionMenu =="2":
        print("GAME OVER")
        break
def rompecabezas():
    mapache = misc.face()
    print("Principal")
    plt.imshow(mapache)
    plt.show()
    partes = input("Ingrese un numero par de division  ")
    rompecabezas1 = np.vsplit(mapache,int(partes))
    piezasI = np.random.permutation(int(partes))
    mrandom = np.concatenate(list(map(lambda x: rompecabezas1[x],piezasI)))
    print("Random")
    plt.imshow(mrandom)
    plt.show()

    rompecabezas()
